# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.3/915.3 kB 12.5 MB/s eta 0:00:0000:0100:01
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolo11m-cls")

result = model.train(
    data='/kaggle/input/tomatodataset/tomato',
    epochs=400,
    imgsz=256, 
    optimizer="AdamW",
    save=True,
    plots=True,
    name='tomatoe_cls_model',
)
# Out:
# ...
# 100%|██████████| 22.4M/22.4M [00:00<00:00, 158MB/s]
# Ultralytics 8.3.77 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
from IPython.display import Image

# %%
Image("/kaggle/working/runs/classify/tomatoe_cls_model/results.png", width=600)

# %%
Image("/kaggle/working/runs/classify/tomatoe_cls_model/confusion_matrix_normalized.png", width=600)
